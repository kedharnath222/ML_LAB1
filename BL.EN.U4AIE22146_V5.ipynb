# %%
def finding_vowels(string):
    count_vowels=0
    count_consonents=0
    vowels="aeiouAEIOU"    
    for char in string:
       if char in vowels:
           count_vowels+=1
       else:
           count_consonents+=1
    return count_consonents, count_vowels
"""MAIN"""
string=input("enter the string: ")
[a,b]=finding_vowels(string)
print("the no of vowels:",b)
# Out:
# the no of vowels: 2

# %%
def multiply_matrices(matrix_A, matrix_B):
    # Determine the dimensions of matrices A and B
    rows_A = len(matrix_A)       # Number of rows in matrix A
    columns_A = len(matrix_A[0]) # Number of columns in matrix A
    rows_B = len(matrix_B)       # Number of rows in matrix B
    columns_B = len(matrix_B[0]) # Number of columns in matrix B

    # Check if matrices A and B are multipliable
    if columns_A != rows_B:
        return "Error: Matrices are not multipliable."

    # Initialize the product matrix with zeros
    product_matrix = [[0 for _ in range(columns_B)] for _ in range(rows_A)]

    # Perform matrix multiplication
    for i in range(rows_A):
        for j in range(columns_B):
            for k in range(columns_A):
                # Checks the dot product for each element of the product matrix
                product_matrix[i][j] += matrix_A[i][k] * matrix_B[k][j]

    return product_matrix

def main():
    # Takes input for the dimensions and elements of matrix A
    rows_A = int(input("Enter the number of rows in matrix A: "))
    columns_A = int(input("Enter the number of columns in matrix A: "))

    matrix_A = []
    print("Enter elements of matrix A row-wise:")
    for _ in range(rows_A):
        row = [int(x) for x in input().split()]
        matrix_A.append(row)

    # Takes input for the dimensions and elements of matrix B
    rows_B = int(input("Enter the number of rows in matrix B: "))
    columns_B = int(input("Enter the number of columns in matrix B: "))

    matrix_B = []
    print("Enter elements of matrix B row-wise:")
    for _ in range(rows_B):
        row = [int(x) for x in input().split()]
        matrix_B.append(row)

    # The product of matrices A and B
    product = multiply_matrices(matrix_A, matrix_B)

    # Print the result
    if isinstance(product, str):
        print(product)
    else:
        print("Product of matrices A and B:")
        for row in product:
            print(row)

if __name__ == "_main_":
    main()

# %%
def common_elements(a, b):

    # Convert lists to sets to find common elements efficiently
    a_set = set(a)
    b_set = set(b)

    # Check if there are common elements between sets
    if (a_set & b_set):
        print("COMMON ELEMENTS: ", a_set & b_set)  # Print common elements if found
    else:
        print("NO COMMON ELEMENTS FOUND")  # Print message if no common elements found

def main():
    # Prompts the user to enter elements for the first list
    a = [int(x) for x in input("ENTER THE ELEMENTS IN FIRST LIST: ").split()]

    # Prompts the user to enter elements for the second list
    b = [int(x) for x in input("ENTER THE ELEMENTS IN SECOND LIST: ").split()]

    # Print common elements between the two lists
    common_elements(a, b)

if __name__ == "main":
    main()

# %%
def transpose_matrix(matrix):
    
    # Gets the number of rows and columns in the matrix
    num_rows = len(matrix)
    num_columns = len(matrix[0])

    # Initialize a matrix to store the transposed matrix
    transposed_matrix = [[0 for _ in range(num_rows)] for _ in range(num_columns)]

    # Iterate through each element of the matrix and transpose it
    for i in range(num_rows):
        for j in range(num_columns):
            transposed_matrix[j][i] = matrix[i][j]

    return transposed_matrix

def main():
    # Prompt the user to input the dimensions of the matrix
    rows = int(input("ENTER NUMBER OF ROWS IN A MATRIX: "))
    columns = int(input("ENTER NUMBER OF COLUMNS IN A MATRIX: "))

    # Prompt the user to input elements for the matrix
    print("ENTER ELEMENTS IN A MATRIX : ")
    matrix = []
    for i in range(rows):
        row = [int(x) for x in input().split()]
        matrix.append(row)

    #  the transpose of the matrix
    transposed_matrix = transpose_matrix(matrix)

    # Print the original matrix
    print("ORIGINAL MATRIX :")
    for row in matrix:
        print(row)

    # Print the transpose of the matrix
    print("TRANSPOSE OF MATRIX: ")
    for row in transposed_matrix:
        print(row)

if __name__ == "main":
    main()
